# %% [markdown]
# # Nestle Stock Price Prediction

# %%
#importing libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('nestle.csv')
df.head()
# Out:
#             Date  Open Price  High Price  Low Price  Close Price  \
# 0  21-April-2022    18150.00    18572.95   17772.90     18205.80
# 1  20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2  19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3  18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4  13-April-2022    18371.20    18549.30   18248.25     18343.90
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  18130.183442          4590           1770            83217542.0
# 1  18295.559071          6069           1321           111035748.0
# 2  18355.093320          2904            716            53303191.0
# 3  18511.224599          1496            586            27692792.0
# 4  18388.967826          1150            550            21147313.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                 950.0                      20.70           800.05
# 1                4677.0                      77.06           397.85
# 2                1619.0                      55.75           872.40
# 3                 557.0                      37.23           390.00
# 4                 573.0                      49.83           301.05
#
#    Spread Close-Open
# 0              55.80
# 1             213.60
# 2            -526.90
# 3             255.35
# 4             -27.30

# %%
#shape/ size of the data
df.shape
# Out:
# (2553, 13)

# %%
df.describe()
# Out:
#          Open Price    High Price     Low Price   Close Price           WAP  \
# count   2553.000000   2553.000000   2553.000000   2553.000000   2553.000000
# mean    9338.023188   9429.710419   9226.855934   9324.960556   9327.503179
# std     4940.554627   4986.783271   4878.971233   4932.776537   4929.373727
# min     3970.000000   3995.000000   3930.000000   3942.450000   3936.768632
# 25%     5391.000000   5445.000000   5327.200000   5383.500000   5385.347807
# 50%     6804.000000   6868.900000   6747.300000   6809.950000   6813.150538
# 75%    13299.950000  13690.950000  12850.000000  13455.450000  13387.505382
# max    20452.000000  20599.950000  20243.800000  20439.450000  20417.372402
#
#         No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# count    2553.000000    2553.000000          2.553000e+03
# mean     5521.380337    1004.099491          4.761923e+07
# std     10416.942384    1137.547557          8.502888e+07
# min        39.000000       6.000000          1.721420e+05
# 25%      1572.000000     442.000000          1.172133e+07
# 50%      2618.000000     731.000000          2.222074e+07
# 75%      4981.000000    1199.000000          4.938465e+07
# max    154684.000000   20964.000000          2.155655e+09
#
#        Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# count           2551.000000                2551.000000      2553.000000
# mean            3264.052528                  49.024461       202.854485
# std             8652.860793                  19.119739       174.985173
# min               33.000000                   1.270000        17.000000
# 25%              653.500000                  35.575000        88.850000
# 50%             1123.000000                  46.870000       152.100000
# 75%             2225.500000                  59.130000       263.150000
# max           152993.000000                  98.930000      1950.000000
#
#        Spread Close-Open
# count        2553.000000
# mean          -13.062632
# std           157.849187
# min         -1381.300000
# 25%           -71.700000
# 50%           -12.750000
# 75%            48.300000
# max          1523.300000

# %%
#printing the data frame column names
df.columns
# Out:
# Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
#dropping the date column
df.drop(['Date'],axis=1,inplace=True)

# %%
#printing dataframe
df
# Out:
#       Open Price  High Price  Low Price  Close Price           WAP  \
# 0       18150.00    18572.95   17772.90     18205.80  18130.183442
# 1       18100.10    18415.00   18017.15     18313.70  18295.559071
# 2       18470.05    18718.00   17845.60     17943.15  18355.093320
# 3       18294.50    18684.50   18294.50     18549.85  18511.224599
# 4       18371.20    18549.30   18248.25     18343.90  18388.967826
# ...          ...         ...        ...          ...           ...
# 2548     4114.00     4160.00    4076.00      4143.25   4129.486321
# 2549     4118.00     4126.90    4080.00      4101.85   4106.848723
# 2550     4100.00     4125.00    4081.40      4120.60   4105.106055
# 2551     4061.00     4110.10    4060.10      4095.35   4091.474315
# 2552     4139.90     4139.90    4044.00      4070.35   4085.640979
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0             4590           1770            83217542.0                 950.0
# 1             6069           1321           111035748.0                4677.0
# 2             2904            716            53303191.0                1619.0
# 3             1496            586            27692792.0                 557.0
# 4             1150            550            21147313.0                 573.0
# ...            ...            ...                   ...                   ...
# 2548          3107            444            12830314.0                2069.0
# 2549          1018            270             4180772.0                 357.0
# 2550          2857            247            11728288.0                2312.0
# 2551          5003            886            20469646.0                2817.0
# 2552          7760           1132            31704574.0                5776.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                         20.70           800.05              55.80
# 1                         77.06           397.85             213.60
# 2                         55.75           872.40            -526.90
# 3                         37.23           390.00             255.35
# 4                         49.83           301.05             -27.30
# ...                         ...              ...                ...
# 2548                      66.59            84.00              29.25
# 2549                      35.07            46.90             -16.15
# 2550                      80.92            43.60              20.60
# 2551                      56.31            50.00              34.35
# 2552                      74.43            95.90             -69.55
#
# [2553 rows x 12 columns]

# %%
#checking data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Open Price                 2553 non-null   float64
#  1   High Price                 2553 non-null   float64
#  2   Low Price                  2553 non-null   float64
#  3   Close Price                2553 non-null   float64
#  4   WAP                        2553 non-null   float64
#  5   No.of Shares               2553 non-null   int64
#  6   No. of Trades              2553 non-null   int64
#  7   Total Turnover (Rs.)       2553 non-null   float64
#  8   Deliverable Quantity       2551 non-null   float64
#  9   % Deli. Qty to Traded Qty  2551 non-null   float64
#  10  Spread High-Low            2553 non-null   float64
#  11  Spread Close-Open          2553 non-null   float64
# dtypes: float64(10), int64(2)
# memory usage: 239.5 KB

# %%
#checking for null values
df.isnull().sum()
# Out:
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         2
# % Deli. Qty to Traded Qty    2
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
#filling null values with the mean of respective columns
df['Deliverable Quantity']=df['Deliverable Quantity'].fillna(df['Deliverable Quantity'].mean())
df['% Deli. Qty to Traded Qty']=df['% Deli. Qty to Traded Qty'].fillna(df['% Deli. Qty to Traded Qty'].mean())
df.isnull().sum()
# Out:
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
#checking the correlation between the columns
df.corr()
# Out:
#                            Open Price  High Price  Low Price  Close Price  \
# Open Price                   1.000000    0.999722   0.999701     0.999490
# High Price                   0.999722    1.000000   0.999610     0.999793
# Low Price                    0.999701    0.999610   1.000000     0.999761
# Close Price                  0.999490    0.999793   0.999761     1.000000
# WAP                          0.999693    0.999879   0.999858     0.999927
# No.of Shares                -0.076134   -0.073740  -0.078191    -0.075764
# No. of Trades                0.155587    0.162156   0.150214     0.156813
# Total Turnover (Rs.)         0.191480    0.194465   0.188937     0.191751
# Deliverable Quantity        -0.092945   -0.092348  -0.093831    -0.093119
# % Deli. Qty to Traded Qty   -0.246590   -0.248456  -0.245064    -0.246715
# Spread High-Low              0.616536    0.627006   0.604996     0.616866
# Spread Close-Open           -0.065212   -0.047052  -0.047372    -0.033314
#
#                                 WAP  No.of Shares  No. of Trades  \
# Open Price                 0.999693     -0.076134       0.155587
# High Price                 0.999879     -0.073740       0.162156
# Low Price                  0.999858     -0.078191       0.150214
# Close Price                0.999927     -0.075764       0.156813
# WAP                        1.000000     -0.075620       0.156683
# No.of Shares              -0.075620      1.000000       0.452116
# No. of Trades              0.156683      0.452116       1.000000
# Total Turnover (Rs.)       0.191979      0.856353       0.464951
# Deliverable Quantity      -0.092992      0.868176       0.103850
# % Deli. Qty to Traded Qty -0.247077      0.279274      -0.188499
# Spread High-Low            0.616620      0.078676       0.432884
# Spread Close-Open         -0.041972      0.015336       0.030636
#
#                            Total Turnover (Rs.)  Deliverable Quantity  \
# Open Price                             0.191480             -0.092945
# High Price                             0.194465             -0.092348
# Low Price                              0.188937             -0.093831
# Close Price                            0.191751             -0.093119
# WAP                                    0.191979             -0.092992
# No.of Shares                           0.856353              0.868176
# No. of Trades                          0.464951              0.103850
# Total Turnover (Rs.)                   1.000000              0.655849
# Deliverable Quantity                   0.655849              1.000000
# % Deli. Qty to Traded Qty              0.192031              0.488715
# Spread High-Low                        0.273972             -0.015545
# Spread Close-Open                     -0.000969             -0.000877
#
#                            % Deli. Qty to Traded Qty  Spread High-Low  \
# Open Price                                 -0.246590         0.616536
# High Price                                 -0.248456         0.627006
# Low Price                                  -0.245064         0.604996
# Close Price                                -0.246715         0.616866
# WAP                                        -0.247077         0.616620
# No.of Shares                                0.279274         0.078676
# No. of Trades                              -0.188499         0.432884
# Total Turnover (Rs.)                        0.192031         0.273972
# Deliverable Quantity                        0.488715        -0.015545
# % Deli. Qty to Traded Qty                   1.000000        -0.247647
# Spread High-Low                            -0.247647         1.000000
# Spread Close-Open                           0.008248        -0.020072
#
#                            Spread Close-Open
# Open Price                         -0.065212
# High Price                         -0.047052
# Low Price                          -0.047372
# Close Price                        -0.033314
# WAP                                -0.041972
# No.of Shares                        0.015336
# No. of Trades                       0.030636
# Total Turnover (Rs.)               -0.000969
# Deliverable Quantity               -0.000877
# % Deli. Qty to Traded Qty           0.008248
# Spread High-Low                    -0.020072
# Spread Close-Open                   1.000000

# %%
#drawing distribution charts
col=df.columns
plt.figure(figsize = (20, 20))
plotnumber = 1
for column in col:
    if plotnumber <= 12:
        ax = plt.subplot(4, 3, plotnumber)
        sns.distplot(df[column],color='blue');
        plt.xlabel(column)  
    plotnumber += 1

# %%
#seperating input and output columns
x=df.drop(['Close Price'],axis=1)
x
# Out:
#       Open Price  High Price  Low Price           WAP  No.of Shares  \
# 0       18150.00    18572.95   17772.90  18130.183442          4590
# 1       18100.10    18415.00   18017.15  18295.559071          6069
# 2       18470.05    18718.00   17845.60  18355.093320          2904
# 3       18294.50    18684.50   18294.50  18511.224599          1496
# 4       18371.20    18549.30   18248.25  18388.967826          1150
# ...          ...         ...        ...           ...           ...
# 2548     4114.00     4160.00    4076.00   4129.486321          3107
# 2549     4118.00     4126.90    4080.00   4106.848723          1018
# 2550     4100.00     4125.00    4081.40   4105.106055          2857
# 2551     4061.00     4110.10    4060.10   4091.474315          5003
# 2552     4139.90     4139.90    4044.00   4085.640979          7760
#
#       No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0              1770            83217542.0                 950.0
# 1              1321           111035748.0                4677.0
# 2               716            53303191.0                1619.0
# 3               586            27692792.0                 557.0
# 4               550            21147313.0                 573.0
# ...             ...                   ...                   ...
# 2548            444            12830314.0                2069.0
# 2549            270             4180772.0                 357.0
# 2550            247            11728288.0                2312.0
# 2551            886            20469646.0                2817.0
# 2552           1132            31704574.0                5776.0
#
#       % Deli. Qty to Traded Qty  Spread High-Low  Spread Close-Open
# 0                         20.70           800.05              55.80
# 1                         77.06           397.85             213.60
# 2                         55.75           872.40            -526.90
# 3                         37.23           390.00             255.35
# 4                         49.83           301.05             -27.30
# ...                         ...              ...                ...
# 2548                      66.59            84.00              29.25
# 2549                      35.07            46.90             -16.15
# 2550                      80.92            43.60              20.60
# 2551                      56.31            50.00              34.35
# 2552                      74.43            95.90             -69.55
#
# [2553 rows x 11 columns]

# %%
y=df.iloc[:,3]
y
# Out:
# 0       18205.80
# 1       18313.70
# 2       17943.15
# 3       18549.85
# 4       18343.90
#           ...
# 2548     4143.25
# 2549     4101.85
# 2550     4120.60
# 2551     4095.35
# 2552     4070.35
# Name: Close Price, Length: 2553, dtype: float64

# %%
#drawing regression plot with the output column
colx=x.columns
plt.figure(figsize = (20, 20))
plotnumber = 1
for column in colx:
    if plotnumber <= 12:
        ax = plt.subplot(4, 3, plotnumber)
        sns.regplot(x=df[column],y=y,color='blue');
        plt.xlabel(column)    
    plotnumber += 1

# %% [markdown]
# since '% Deli. Qty to Traded Qty' and 'Spread Close-Open' are not showing any co-relation with the close price, we can drop them

# %%
#adjusting the input features
x=df.drop(['% Deli. Qty to Traded Qty','Spread Close-Open'],axis=1)
x
# Out:
#       Open Price  High Price  Low Price  Close Price           WAP  \
# 0       18150.00    18572.95   17772.90     18205.80  18130.183442
# 1       18100.10    18415.00   18017.15     18313.70  18295.559071
# 2       18470.05    18718.00   17845.60     17943.15  18355.093320
# 3       18294.50    18684.50   18294.50     18549.85  18511.224599
# 4       18371.20    18549.30   18248.25     18343.90  18388.967826
# ...          ...         ...        ...          ...           ...
# 2548     4114.00     4160.00    4076.00      4143.25   4129.486321
# 2549     4118.00     4126.90    4080.00      4101.85   4106.848723
# 2550     4100.00     4125.00    4081.40      4120.60   4105.106055
# 2551     4061.00     4110.10    4060.10      4095.35   4091.474315
# 2552     4139.90     4139.90    4044.00      4070.35   4085.640979
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0             4590           1770            83217542.0                 950.0
# 1             6069           1321           111035748.0                4677.0
# 2             2904            716            53303191.0                1619.0
# 3             1496            586            27692792.0                 557.0
# 4             1150            550            21147313.0                 573.0
# ...            ...            ...                   ...                   ...
# 2548          3107            444            12830314.0                2069.0
# 2549          1018            270             4180772.0                 357.0
# 2550          2857            247            11728288.0                2312.0
# 2551          5003            886            20469646.0                2817.0
# 2552          7760           1132            31704574.0                5776.0
#
#       Spread High-Low
# 0              800.05
# 1              397.85
# 2              872.40
# 3              390.00
# 4              301.05
# ...               ...
# 2548            84.00
# 2549            46.90
# 2550            43.60
# 2551            50.00
# 2552            95.90
#
# [2553 rows x 10 columns]

# %%
#converting data to training data and testing data
from sklearn.model_selection import train_test_split
#splitting 70% of the data to training data and 30% of data to testing data
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
#checking the split
print(x_train.shape,x_test.shape,y_train.shape,y_test.shape)
# Out:
# (1787, 10) (766, 10) (1787,) (766,)

# %%
#model creation
from sklearn.linear_model import LinearRegression
reg= LinearRegression()
reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#generation y_pred from x_test
y_pred=reg.predict(x_test)
y_pred.shape
# Out:
# (766,)

# %%
#c - y intercept
print("y intercept",reg.intercept_)
# Out:
# y intercept 1.8189894035458565e-12

# %%
#m - slop/ coefficence
print("slop/ coefficence",reg.coef_)
# var=['R&D Spend','Administration','Marketing Spend','State']
list(zip(x.columns,reg.coef_))
# Out:
# slop/ coefficence [ 3.06291656e-14  1.44662686e-13 -1.73415177e-13  1.00000000e+00
#  -4.95604880e-15  3.88949337e-16  2.81233022e-17 -9.88131978e-20
#   1.44455458e-16 -1.71550745e-13]
# [('Open Price', 3.0629165613938386e-14),
#  ('High Price', 1.4466268626207802e-13),
#  ('Low Price', -1.7341517673362178e-13),
#  ('Close Price', 1.0000000000000033),
#  ('WAP', -4.956048802999189e-15),
#  ('No.of Shares', 3.8894933676603243e-16),
#  ('No. of Trades', 2.8123302223390914e-17),
#  ('Total Turnover (Rs.)', -9.881319775717232e-20),
#  ('Deliverable Quantity', 1.4445545796564077e-16),
#  ('Spread High-Low', -1.7155074469739974e-13)]

# %%
#comparing actual value and predicted value in a new df
df_pred=pd.DataFrame({"actual_value":y_test,"predicted_value":y_pred})
df_pred
# Out:
#       actual_value  predicted_value
# 1949       4812.95          4812.95
# 637       13945.10         13945.10
# 2150       5101.50          5101.50
# 393       16098.90         16098.90
# 1023       7850.55          7850.55
# ...            ...              ...
# 1755       7397.90          7397.90
# 642       12699.45         12699.45
# 1301       5883.05          5883.05
# 311       17872.25         17872.25
# 351       16865.75         16865.75
#
# [766 rows x 2 columns]

# %%
#importng Evaluation marics
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error,r2_score

# %%
#MAE,MAPE,accuracy
print("mean_absolute_error is",mean_absolute_error(y_test,y_pred))
print("error percentage is",mean_absolute_percentage_error(y_test,y_pred))
print("accuracy is",1-mean_absolute_percentage_error(y_test,y_pred))
# Out:
# mean_absolute_error is 3.3043391057885892e-12
# error percentage is 3.873492330423843e-16
# accuracy is 0.9999999999999997

# %%
#MSE, RMSE
print("mean_squared_error is",mean_squared_error(y_test,y_pred))
print("root mean squared error is: ", np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# mean_squared_error is 3.472970715446204e-23
# root mean squared error is:  5.8931915932253584e-12

# %%
#R2 score
print("r2_score is",r2_score(y_test,y_pred))
# Out:
# r2_score is 1.0
